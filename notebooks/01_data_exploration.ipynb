# %% [markdown]
# # 01 — Data Download & Exploration
#
# **OandaFX** — Clone the repo, download raw OANDA candle data, validate quality, and save to Google Drive.
#
# **This is the first notebook in the pipeline.** It downloads all raw data and saves it to Drive so that notebooks 02–04 can load it directly without re-downloading.

# %%
# ─── Mount Google Drive & Clone Repo ────────────────────────────
import sys, os

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    DRIVE_BASE = '/content/drive/MyDrive/oandafx'
    os.makedirs(DRIVE_BASE, exist_ok=True)

    # Clone the repository
    if not os.path.exists('/content/wavebot-v1'):
        # !git clone https://github.com/Unseengap/wavebot-v1.git /content/wavebot-v1
    sys.path.insert(0, '/content/wavebot-v1')

    # Install dependencies
    # !pip install -q oandapyV20 pandas pyarrow ta-lib matplotlib seaborn tqdm
else:
    DRIVE_BASE = os.path.abspath(os.path.join(os.getcwd(), '..'))
    sys.path.insert(0, DRIVE_BASE)

# Data directories
RAW_DIR = os.path.join(DRIVE_BASE, 'data', 'raw')
os.makedirs(RAW_DIR, exist_ok=True)
print(f'Drive base: {DRIVE_BASE}')
print(f'Raw data dir: {RAW_DIR}')
print(f'Raw data exists: {os.path.exists(RAW_DIR)}')

# %% [markdown]
# ## Download Raw Data from OANDA
#
# Set your OANDA API credentials below, then run the download cell.
# This fetches M15, H1, H4, and Daily candles for the 7 major pairs going back to 2010.
#
# **Expected time:** 20–40 minutes depending on connection speed.
# **Expected size:** ~2–4 GB of Parquet files.

# %%
# ─── Download Historical Data from OANDA ─────────────────────────
# Set your OANDA credentials here (or they'll be read from environment variables)
OANDA_API_KEY = ""        # paste your OANDA API key here
OANDA_ACCOUNT_ID = ""     # paste your OANDA account ID here
OANDA_ENVIRONMENT = "practice"  # "practice" or "live"

# ─── Check if data already exists on Drive ───────────────────────
from pathlib import Path
existing_pairs = [d.name for d in Path(RAW_DIR).iterdir() if d.is_dir()] if os.path.exists(RAW_DIR) else []

if existing_pairs:
    print(f'⚠️  Raw data already exists on Drive: {existing_pairs}')
    print('   Skipping download. Delete data/raw/ on Drive to force re-download.')
    SKIP_DOWNLOAD = True
else:
    SKIP_DOWNLOAD = False

if not SKIP_DOWNLOAD:
    import os as _os
    # Set env vars for the download script
    if OANDA_API_KEY:
        _os.environ['OANDA_API_KEY_1'] = OANDA_API_KEY
    if OANDA_ACCOUNT_ID:
        _os.environ['OANDA_ACCOUNT_ID_1'] = OANDA_ACCOUNT_ID

    if not _os.environ.get('OANDA_API_KEY_1') or not _os.environ.get('OANDA_ACCOUNT_ID_1'):
        print('❌ ERROR: Set OANDA_API_KEY and OANDA_ACCOUNT_ID above, or set environment variables.')
        print('   OANDA_API_KEY_1 and OANDA_ACCOUNT_ID_1')
    else:
        repo_root = '/content/wavebot-v1' if IN_COLAB else DRIVE_BASE

        # !python {repo_root}/scripts/download_history.py \
            --pairs EUR_USD GBP_USD USD_JPY AUD_USD USD_CHF USD_CAD NZD_USD \
            --granularities M15 H1 H4 D \
            --start 2010-01-01 \
            --output-dir {RAW_DIR} \
            --environment {OANDA_ENVIRONMENT} \
            --verbose

        # Verify download
        downloaded = [d.name for d in Path(RAW_DIR).iterdir() if d.is_dir()]
        print(f'\n✅ Downloaded pairs: {downloaded}')

# %%
# ─── Imports ─────────────────────────────────────────────────────
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from src.data.storage import load_candles, detect_gaps, detect_anomalies

plt.style.use('dark_background')
sns.set_palette('Set2')
pd.set_option('display.max_columns', 30)
pd.set_option('display.float_format', '{:.5f}'.format)

DATA_DIR = RAW_DIR  # Use raw data dir set in setup cell

# %%
# ─── Discover Available Data ─────────────────────────────────────
data_path = Path(DATA_DIR)
pairs = sorted([d.name for d in data_path.iterdir() if d.is_dir()]) if data_path.exists() else []
print(f'Pairs found: {pairs}\n')

# Inventory
inventory = []
for pair in pairs:
    pair_dir = data_path / pair
    for f in sorted(pair_dir.glob('*.parquet')):
        df = load_candles(f)
        inventory.append({
            'Pair': pair,
            'Timeframe': f.stem,
            'Bars': len(df),
            'Start': df['time'].min() if not df.empty else None,
            'End': df['time'].max() if not df.empty else None,
        })

inv_df = pd.DataFrame(inventory)
display(inv_df)

# %% [markdown]
# ## Price Visualization

# %%
# ─── Plot price series for each pair (Daily) ────────────────────
fig, axes = plt.subplots(len(pairs), 1, figsize=(16, 4 * len(pairs)), sharex=False)
if len(pairs) == 1:
    axes = [axes]

for ax, pair in zip(axes, pairs):
    path = data_path / pair / 'D.parquet'
    if not path.exists():
        continue
    df = load_candles(path)
    ax.plot(df['time'], df['close'], linewidth=0.7)
    ax.set_title(f'{pair} — Daily Close', fontsize=13)
    ax.set_ylabel('Price')
    ax.grid(alpha=0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Data Quality Checks

# %%
# ─── Gap Detection ───────────────────────────────────────────────
GRANULARITY_SECONDS = {'M15': 900, 'H1': 3600, 'H4': 14400, 'D': 86400}

for pair in pairs:
    for tf, secs in GRANULARITY_SECONDS.items():
        path = data_path / pair / f'{tf}.parquet'
        if not path.exists():
            continue
        df = load_candles(path)
        gaps = detect_gaps(df, secs)
        if not gaps.empty:
            print(f'\n⚠️  {pair}/{tf}: {len(gaps)} gaps detected')
            display(gaps.head(5))
        else:
            print(f'✅ {pair}/{tf}: No gaps')

# %%
# ─── Anomaly Detection (bars with range > 5× ATR) ────────────────
for pair in pairs[:3]:  # Check first 3 pairs
    path = data_path / pair / 'M15.parquet'
    if not path.exists():
        continue
    df = load_candles(path)
    anomalies = detect_anomalies(df, atr_multiplier=5.0)
    if not anomalies.empty:
        print(f'\n⚠️  {pair}/M15: {len(anomalies)} anomalous bars')
        display(anomalies[['time', 'open', 'high', 'low', 'close', 'bar_range', 'atr_20']].head(5))
    else:
        print(f'✅ {pair}/M15: No anomalies')

# %% [markdown]
# ## Spread Analysis

# %%
# ─── Spread Distribution ─────────────────────────────────────────
pair = pairs[0] if pairs else 'EUR_USD'
df = load_candles(data_path / pair / 'M15.parquet')

if 'bid_close' in df.columns and 'ask_close' in df.columns:
    df['spread'] = df['ask_close'] - df['bid_close']
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    
    ax1.hist(df['spread'].dropna(), bins=100, alpha=0.7, color='cyan')
    ax1.set_title(f'{pair} — Spread Distribution (M15)')
    ax1.set_xlabel('Spread (price units)')
    ax1.axvline(df['spread'].median(), color='red', linestyle='--', label=f'Median: {df["spread"].median():.6f}')
    ax1.legend()
    
    # Spread by hour of day
    df['hour'] = pd.to_datetime(df['time']).dt.hour
    hourly_spread = df.groupby('hour')['spread'].mean()
    ax2.bar(hourly_spread.index, hourly_spread.values, color='cyan', alpha=0.7)
    ax2.set_title(f'{pair} — Average Spread by Hour (UTC)')
    ax2.set_xlabel('Hour (UTC)')
    
    plt.tight_layout()
    plt.show()
else:
    print('No bid/ask data available — download with price=BA')

# %% [markdown]
# ## Volume & Pair Correlations

# %%
# ─── Pair Return Correlations ────────────────────────────────────
returns = {}
for pair in pairs:
    path = data_path / pair / 'D.parquet'
    if not path.exists():
        continue
    df = load_candles(path)
    if not df.empty:
        returns[pair] = np.log(df['close'] / df['close'].shift(1)).values[1:]

if returns:
    min_len = min(len(v) for v in returns.values())
    ret_df = pd.DataFrame({k: v[:min_len] for k, v in returns.items()})
    
    fig, ax = plt.subplots(figsize=(10, 8))
    sns.heatmap(ret_df.corr(), annot=True, fmt='.2f', cmap='coolwarm', center=0, ax=ax)
    ax.set_title('Daily Return Correlations')
    plt.tight_layout()
    plt.show()

# %%
# ─── Save Summary & Verify Data on Drive ─────────────────────────
summary_path = os.path.join(DRIVE_BASE, 'data', 'data_exploration_summary.csv')
os.makedirs(os.path.dirname(summary_path), exist_ok=True)
inv_df.to_csv(summary_path, index=False)
print(f'Summary saved to {summary_path}')

# Verify all data is on Drive
print(f'\n{"=" * 60}')
print('DATA ON GOOGLE DRIVE (available for notebooks 02-04):')
print(f'{"=" * 60}')
data_path = Path(RAW_DIR)
total_files = 0
for pair_dir in sorted(data_path.iterdir()):
    if pair_dir.is_dir():
        files = list(pair_dir.glob('*.parquet'))
        total_files += len(files)
        tfs = [f.stem for f in files]
        print(f'  {pair_dir.name}: {tfs}')
print(f'\nTotal: {total_files} Parquet files on Drive')
print(f'Path: {RAW_DIR}')
print(f'\n✅ Notebook 02 can now load this data from Drive.')
